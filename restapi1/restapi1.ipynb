# %%
import pandas as pd
import numpy as np
import requests
import os
import zipfile
import xlsxwriter
from sqlalchemy import create_engine

# %%
model = 'camry'
api_url = 'https://api.api-ninjas.com/v1/cars?model={}'.format(model)
response = requests.get(api_url, headers={'X-Api-Key': '7B1HcPnYvhvescmIPEsC6A==mThqXWQVgvMo1l7U'})
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"city_mpg": 18, "class": "midsize car", "combination_mpg": 21, "cylinders": 4, "displacement": 2.2, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "camry", "transmission": "a", "year": 1993}, {"city_mpg": 19, "class": "midsize car", "combination_mpg": 22, "cylinders": 4, "displacement": 2.2, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 27, "make": "toyota", "model": "camry", "transmission": "m", "year": 1993}, {"city_mpg": 16, "class": "midsize car", "combination_mpg": 19, "cylinders": 6, "displacement": 3.0, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 22, "make": "toyota", "model": "camry", "transmission": "a", "year": 1993}, {"city_mpg": 16, "class": "midsize car", "combination_mpg": 18, "cylinders": 6, "displacement": 3.0, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 22, "make": "toyota", "model": "camry", "transmission": "m", "year": 1993}, {"city_mpg": 18, "class": "midsize-large station wagon", "combination_mpg": 21, "cylinders": 4, "displacement": 2.2, "drive": "fwd", "fuel_type": "gas", "highway_mpg": 26, "make": "toyota", "model": "camry wagon", "transmission": "a", "year": 1993}]

# %%
class ApiClient:
        def __init__(self, base_url):
                self.base_url = base_url
                
        def make_requests( self, endpoint, params=None):
                try:
                        # Construct the full URL
                        url = f"{self.base_url}/{endpoint}"
                        # Make a GET request to the API
                        response = requests.get(api_url, headers={'X-Api-Key': 'key'})
                        
                        # check if the request was siccessfi; ) statis cpde 200)
                        if response.status_code == 200:
                                return response.json()
                        else:
                                print(f' Request failed with status code : {response.status_code}')
                                return None
                except requests.exceptions.RequestException as e:
                        print( f'Request failed with an exception : {e}')
                        return None

# %%
# Function to use the ApiClient class
def get_api_response( api_client, endpoint, params=None):
        return api_client.make_requests( endpoint, params)

# %%
model = 'camry'
api_url = 'https://api.api-ninjas.com/v1/cars?model={}'.format(model)

base_url = r'https://api.api-ninjas.com/v1/cars?model='
endpoint = model
api_client = ApiClient(base_url)

model=''
base_url = r'https://api.api-ninjas.com/v1/cars?limit=2&model='
response_data = get_api_response(api_client, endpoint)

print( response_data )
# Out:
# [{'city_mpg': 18, 'class': 'midsize car', 'combination_mpg': 21, 'cylinders': 4, 'displacement': 2.2, 'drive': 'fwd', 'fuel_type': 'gas', 'highway_mpg': 26, 'make': 'toyota', 'model': 'camry', 'transmission': 'a', 'year': 1993}, {'city_mpg': 19, 'class': 'midsize car', 'combination_mpg': 22, 'cylinders': 4, 'displacement': 2.2, 'drive': 'fwd', 'fuel_type': 'gas', 'highway_mpg': 27, 'make': 'toyota', 'model': 'camry', 'transmission': 'm', 'year': 1993}, {'city_mpg': 16, 'class': 'midsize car', 'combination_mpg': 19, 'cylinders': 6, 'displacement': 3.0, 'drive': 'fwd', 'fuel_type': 'gas', 'highway_mpg': 22, 'make': 'toyota', 'model': 'camry', 'transmission': 'a', 'year': 1993}, {'city_mpg': 16, 'class': 'midsize car', 'combination_mpg': 18, 'cylinders': 6, 'displacement': 3.0, 'drive': 'fwd', 'fuel_type': 'gas', 'highway_mpg': 22, 'make': 'toyota', 'model': 'camry', 'transmission': 'm', 'year': 1993}, {'city_mpg': 18, 'class': 'midsize-large station wagon', 'combination_mpg': 21, 'cylinders': 4, 'displacement': 2.2, 'drive': 'fwd', 'fuel_type': 'gas', 'highway_mpg': 26, 'make': 'toyota', 'model': 'camry wagon', 'transmission': 'a', 'year': 1993}]

# %%
model=''
company = 'Honda'
base_url_bikes = f'https://api.api-ninjas.com/v1/motorcycles?make={company}&model='
api_client_bikes = ApiClient(base_url_bikes)
endpoint_bike = ''
response_data_bikes = get_api_response(api_client_bikes, '') 
# print( response_data )
print( response_data_bikes )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb Cell 6 line 6
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> api_client_bikes = ApiClient(base_url_bikes)
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> endpoint_bike = ''
# ----> <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> response_data_bikes = get_api_response(api_client_bikes, '')
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> # print( response_data )
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> print( response_data_bikes )
#
# /home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> def get_api_response( api_client, endpoint, params=None):
# ----> <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>         return api_client.make_requests( endpoint, params)
#
# /home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> url = f"{self.base_url}/{endpoint}"
#       <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> # Make a GET request to the API
# ---> <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> response = requests.get(api_url, headers={'X-Api-Key': '7B1HcPnYvhvescmIPEsC6A==mThqXWQVgvMo1l7U'})
#      <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> # check if the request was siccessfi; ) statis cpde 200)
#      <a href='vscode-notebook-cell:/home/r/git_projekty/dataProjects/restapi1/restapi1.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> if response.status_code == 200:
#
# NameError: name 'api_url' is not defined

# %%
# cars = pd.DataFrame(response_data)
bikes = pd.DataFrame(response_data_bikes)
